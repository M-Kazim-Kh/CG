# %%
import pygame
import math

def draw_circle(screen, center_x, center_y, radius):
    # Clear the screen
    screen.fill(WHITE)
    
    # Draw the circle using the basic circle equation:
    # (x - xc)^2 + (y - yc)^2 = r^2
    for x in range(center_x - radius, center_x + radius + 1):
        dx = x - center_x
        square_term = radius**2 - dx**2

        # Make sure the value under the square root is non-negative
        if square_term < 0:
            continue  # Skip invalid points due to floating-point errors

        dy = math.sqrt(square_term)
        y1 = round(center_y - dy)  # Top point
        y2 = round(center_y + dy)  # Bottom point

        # Make sure points are within logical screen bounds
        if 0 <= x < WIDTH and 0 <= y1 < HEIGHT:
            pygame.draw.rect(screen, BLACK, (x * PIXEL_SIZE, y1 * PIXEL_SIZE, PIXEL_SIZE, PIXEL_SIZE))
        if 0 <= x < WIDTH and 0 <= y2 < HEIGHT:
            pygame.draw.rect(screen, BLACK, (x * PIXEL_SIZE, y2 * PIXEL_SIZE, PIXEL_SIZE, PIXEL_SIZE))

    # Update the display
    pygame.display.flip()

if __name__ == "__main__":
    # Logical screen settings
    WIDTH, HEIGHT = 50, 50            # Logical resolution in pixels
    PIXEL_SIZE = 10                   # Size of each logical pixel on screen
    WHITE = (255, 255, 255)
    BLACK = (0, 0, 0)

    # Circle parameters
    center = (WIDTH // 2, HEIGHT // 2)
    radius = 20                       # Radius in logical pixels

    # Initialize Pygame
    pygame.init()
    screen = pygame.display.set_mode((WIDTH * PIXEL_SIZE, HEIGHT * PIXEL_SIZE))
    pygame.display.set_caption("Circle Drawing Using Basic Equation")

    # Draw the circle
    draw_circle(screen, *center, radius)

    # Main loop to keep the window open
    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT or (
               event.type == pygame.KEYDOWN and event.key == pygame.K_ESCAPE):
                running = False

    # Quit Pygame
    pygame.quit()

# %%
import pygame
import math

def draw_circle(screen, center_x, center_y, radius):
    # Clear the screen
    screen.fill(WHITE)
    
    # Draw the circle using the circle equation (x - h)^2 + (y - k)^2 = r^2
    for x in range(center_x - radius, center_x + radius + 1):
        dx = x - center_x
        if abs(dx) > radius:
            continue  # Skip invalid x values
        dy = math.sqrt(radius**2 - dx**2)
        y1 = round(center_y - dy)  # Upper point
        y2 = round(center_y + dy)  # Lower point

        # Ensure the points are within the screen bounds
        pygame.draw.rect(screen, BLACK, (x * PIXEL_SIZE, y1 * PIXEL_SIZE, PIXEL_SIZE, PIXEL_SIZE))
        pygame.draw.rect(screen, BLACK, (x * PIXEL_SIZE, y2 * PIXEL_SIZE, PIXEL_SIZE, PIXEL_SIZE))
    
    # Update the display
    pygame.display.flip()


if __name__ == "__main__":
    # Constants
    WIDTH, HEIGHT = 50, 50               # Logical screen size in pixels
    PIXEL_SIZE = 15                      # Size of each logical pixel on screen
    WHITE = (255, 255, 255)
    BLACK = (0, 0, 0)

    # Circle parameters
    center = (WIDTH // 2, HEIGHT // 2)
    radius = 20                         # Use a radius that fits within the logical screen

    # Initialize Pygame
    pygame.init()
    screen = pygame.display.set_mode((WIDTH * PIXEL_SIZE, HEIGHT * PIXEL_SIZE))
    pygame.display.set_caption("Circle Drawing Using Circle Equation")

    # Draw the circle
    draw_circle(screen, *center, radius)

    # Main loop to keep window open
    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT or (
               event.type == pygame.KEYDOWN and event.key == pygame.K_ESCAPE):
                running = False

    # Quit Pygame
    pygame.quit()

# %%
import pygame
import math

# Constants
WIDTH, HEIGHT = 800, 600
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)

def draw_circle(screen, center_x, center_y, radius):
    # Clear the screen
    screen.fill(WHITE)

    # Draw the circle using the basic circle equation: (x - xc)^2 + (y - yc)^2 = r^2
    for x in range(center_x - radius, center_x + radius + 1):
        dx = x - center_x
        square_term = radius**2 - dx**2

        if square_term >= 0:
            dy = math.sqrt(square_term)
            y_top = round(center_y - dy)
            y_bottom = round(center_y + dy)

            # Plot the two symmetric points for this x
            screen.set_at((x, y_top), BLACK)
            screen.set_at((x, y_bottom), BLACK)

    # Update the display
    pygame.display.flip()

if __name__ == "__main__":
    # Circle parameters
    center = (WIDTH // 2, HEIGHT // 2)
    radius = 150

    # Initialize Pygame
    pygame.init()
    screen = pygame.display.set_mode((WIDTH, HEIGHT))
    pygame.display.set_caption("Circle Drawing Using Basic Equation")

    # Draw the circle
    draw_circle(screen, *center, radius)

    # Main loop
    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT or (
                event.type == pygame.KEYDOWN and event.key == pygame.K_ESCAPE):
                running = False

    pygame.quit()

# %%
import pygame
import math

def draw_circle(screen, center_x, center_y, radius):
    # Clear the screen
    screen.fill(WHITE)
    
    # Draw the circle using the circle equation
    for x in range(center_x - radius, center_x + radius + 1):
        # Calculate y coordinates using the circle equation: (x - h)^2 + (y - k)^2 = r^2
        dx = x - center_x
        if abs(dx) > radius:
            continue  # Skip invalid x values
        dy = math.sqrt(radius**2 - dx**2)
        y1 = round(center_y - dy)  # Upper half
        y2 = round(center_y + dy)  # Lower half
        
        # Set pixels at (x, y1) and (x, y2)
        pygame.draw.rect(screen, BLACK, (x * PIXEL_SIZE, y1 * PIXEL_SIZE, PIXEL_SIZE, PIXEL_SIZE))
        pygame.draw.rect(screen, BLACK, (x * PIXEL_SIZE, y2 * PIXEL_SIZE, PIXEL_SIZE, PIXEL_SIZE))
    
    # Update the display
    pygame.display.flip()


if __name__ == "__main__":
    # Constants
    WIDTH, HEIGHT = 50, 50
    PIXEL_SIZE = 15              # Scaling factor for visible pixel size
    WHITE = (255, 255, 255)
    BLACK = (0, 0, 0)

    # Circle parameters
    center = (WIDTH // 2, HEIGHT // 2)
    radius = 40

    # Initialize Pygame
    pygame.init()
    screen = pygame.display.set_mode((WIDTH * PIXEL_SIZE, HEIGHT * PIXEL_SIZE))
    pygame.display.set_caption("Circle Drawing Using Circle Equation")

    # Draw the circle
    draw_circle(screen, *center, radius)

    # Main loop
    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
            elif event.type == pygame.KEYDOWN:
                if event.key == pygame.K_ESCAPE:
                    running = False

    # Quit Pygame
    pygame.quit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html
