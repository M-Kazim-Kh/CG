# %%
from PIL import Image, ImageDraw

image = Image.new("RGB", (600, 400), "white")
draw = ImageDraw.Draw(image)

# Draw a rectangle
draw.rectangle((50, 50, 250, 150), fill="red")

# Draw a circle (ellipse)
draw.ellipse((300, 100, 400, 200), fill="blue")

# Draw a line
draw.line((50, 300, 550, 300), fill="green", width=5)

image.save("shapes.png")
image.show()

# %%
import os
os.startfile("shapes.png")
