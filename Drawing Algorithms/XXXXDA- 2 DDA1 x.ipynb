# %%
import pygame
# import pygame.gfxdraw

# Function to draw a line using DDA
def DDA(x0, y0, x1, y1):
    # Calculate differences
    dx = x1 - x0
    dy = y1 - y0

    # Determine the number of steps
    steps = max(abs(dx), abs(dy))

    # Calculate increments
    x_inc = dx / steps if steps !=0 else 0
    y_inc = dy / steps if steps !=0 else 0

    # Initialize starting point
    x, y = x0, y0

    Pixels=[]

    # Create the line' Pixels
    for _ in range(steps+1):
        Pixels.append((round(x),round(y)))
        x += x_inc
        y += y_inc

    return Pixels


if __name__ == "__main__":
    # Set up display
    screen = pygame.display.set_mode((800, 600))
    pygame.display.set_caption("Digital Differential Analyzer (DDA) Algorithm")
    screen.fill((255,255,255))

    x0, y0, x1, y1 = 50, 50, 700, 500  # Line endpoints
    pixels=DDA(x0, y0, x1, y1)
    # print(pixels)

    for x,y in pixels:
        screen.set_at((round(x),round(y)), (0,0,0))

    # Update the display
    pygame.display.flip()


    # Main loop to keep the window open
    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
            elif event.type == pygame.KEYDOWN and event.key == pygame.K_ESCAPE:
                running = False

    pygame.quit()

# %%
import pygame, pygame.gfxdraw

# Function to draw a line using DDA
def draw_line_dda(x0, y0, x1, y1):
    # Calculate differences
    dx = x1 - x0
    dy = y1 - y0

    # Determine the number of steps
    steps = max(abs(dx), abs(dy))

    # Calculate increments
    x_inc = dx / steps if steps !=0 else 0
    y_inc = dy / steps if steps !=0 else 0

    # Initialize starting point
    x, y = x0, y0

    Pixels=[]

    # Create the line' Pixels
    for _ in range(steps+1):
        Pixels.append((round(x),round(y)))
        x += x_inc
        y += y_inc

        # Remove the comment to step by step drawing
        # pygame.display.flip()
    return Pixels

# Function to draw pixels on a scaled Pygame window
def draw_pixels(res_w, res_h, scale=1):
    pygame.init()
    """
    :param pixels: List of (x, y) pixel coordinates.
    :param res_w: Resolution width of the drawing area.
    :param res_h: Resolution height of the drawing area.
    :param scale: Scaling factor for enlarging the display.
    """
    # Create a temporary surface with a white background
    temp_surface = pygame.Surface((res_w, res_h))
    temp_surface.fill((255, 255, 255))
    
    
    # Create the main window with the scaled size
    screen = pygame.display.set_mode((res_w * scale, res_h * scale))

    x0, y0, x1, y1 = 50, 10, 250, 270  # Line endpoints
    # pixels = [(3, 3), (4, 4), (5, 5)]
    temp_surface.fill((255, 255, 255))

    pixels=draw_line_dda(x0, y0, x1, y1)
    for x, y in pixels:
        pygame.gfxdraw.pixel(temp_surface, x, y, (0, 0, 0))
    
    # Scale the temporary surface to match the display size
    scaled_surface = pygame.transform.scale(temp_surface, (res_w * scale, res_h * scale))
    
    # Blit the scaled surface onto the screen
    screen.blit(scaled_surface, (0, 0))
    pygame.display.update()
    pygame.time.wait(10)
    return scaled_surface


# ---
# Example pixel coordinates
screen=draw_pixels(300, 300, 1)
# Draw each pixel



# 
# 
# Main loop to keep the window open
running = True
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
        elif event.type == pygame.KEYDOWN and event.key == pygame.K_ESCAPE:
            running = False

pygame.quit()

# %%
# Function to draw a line using DDA
def draw_line_dda(x0, y0, x1, y1):
    # Calculate differences
    dx = x1 - x0
    dy = y1 - y0

    # Determine the number of steps
    steps = max(abs(dx), abs(dy))

    # Calculate increments
    x_inc = dx / steps if steps !=0 else 0
    y_inc = dy / steps if steps !=0 else 0

    # Initialize starting point
    x, y = x0, y0

    Pixels=[]
    # Create the line' Pixels
    for _ in range(steps+1):
        Pixels.append((round(x),round(y)))
        x += x_inc
        y += y_inc

        # Remove the comment to step by step drawing
        # pygame.display.flip()
    return Pixels


if __name__ == "__main__": 
    x0, y0, x1, y1 = 3, 3, 150, 100  # Line endpoints
    for i in range(10):
        pixels=draw_line_dda(x0, y0, x1, y1+i)
        print(pixels)
        draw_pixels(pixels,200,200,3)

    # Main loop to keep the window open
    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
            elif event.type == pygame.KEYDOWN and event.key == pygame.K_ESCAPE:
                running = False

    pygame.quit()

# %%
pygame.init()

def DrawPixels(Pixels, Res_W, Res_H, Scale=1):
    # Create a temporary surface
    temp_surface = pygame.Surface((Res_W, Res_H))
    temp_surface.fill((255, 255, 255))
    # Create a main window (screen)
    screen = pygame.display.set_mode((Res_W * Scale, Res_H * Scale))
    for p in Pixels:
        x,y=p[0], p[1]
        pygame.gfxdraw.pixel(temp_surface, x,y, (255,0,0))

    temp_surface = pygame.transform.scale(temp_surface, (Res_W * Scale, Res_H * Scale))
    screen.blit(temp_surface, (0, 0))

    # Copy the temporary surface to the screen
    pygame.display.update()


Pixels=[(3,3),(4,4),(5,5)]
DrawPixels(Pixels,30,30,15)

# Main loop
running = True
while running:
    for event in pygame.event.get():
        if event.type == pygame.KEYDOWN:
            if event.key == pygame.K_ESCAPE: running = False

pygame.quit()

# %%
import pygame

pygame.init()

# إنشاء شاشة صغيرة (مثلاً 100x100)
small_screen = pygame.Surface((100, 100))
screen = pygame.display.set_mode((600, 400))  # تكبيرها لاحقًا

small_screen.fill((255, 255, 255))
x,y=3,3
pygame.gfxdraw.pixel(small_screen, x,y, (0,0,0))

# تكبير الشاشة الصغيرة إلى 4 أضعاف حجمها
scaled_screen = pygame.transform.scale(small_screen, (400, 400))
big_screen.blit(scaled_screen, (0, 0))

pygame.display.update()

# Main loop
running = True
while running:
    for event in pygame.event.get():
        if event.type == pygame.KEYDOWN:
            if event.key == pygame.K_ESCAPE: running = False

pygame.quit()

# %%
import sys,pygame
from pygame import gfxdraw

# Function to draw a line using DDA
def draw_line_dda(x0, y0, x1, y1):
    # Calculate differences
    dx = x1 - x0
    dy = y1 - y0

    # Determine the number of steps
    steps = max(abs(dx), abs(dy))

    # Calculate increments
    x_inc = dx / steps if steps !=0 else 0
    y_inc = dy / steps if steps !=0 else 0

    # Initialize starting point
    x, y = x0, y0

    # Draw the line
    for _ in range(steps+1):
        gfxdraw.pixel(transformsmall_screen, round(x),round(y), Black)
        # gfxdraw.box(screen, (round(x),round(y),length,length), Black)
        # pygame.draw.rect(screen, Black, (round(x),round(y)+length+3,length,length))
        x += x_inc
        y += y_inc

        # Remove the comment to step by step drawing
        # pygame.display.flip()



if __name__ == "__main__": 
    Black=(0,0,0)
    White=(255,255,255)

    # Set up display
    transformsmall_screen = pygame.Surface((100, 100))
    screen = pygame.display.set_mode((800, 600))
    pygame.display.set_caption("Digital Differential Analyzer (DDA) Algorithm")
    screen.fill(White)
    transformsmall_screen.fill(White)

    length=1
    x0, y0, x1, y1 = 50, 50, 700, 500  # Line endpoints
    draw_line_dda(x0, y0, x1, y1)
    pygame.display.flip()
    # font = pygame.font.Font("freesansbold.ttf", 13)
    # text_surface = font.render(f"({x0},{y0})", True, Black)
    # screen.blit(text_surface, (x0, y0-17))
    # text_surface = font.render(f"({x1},{y1})", True, Black)
    # screen.blit(text_surface, (x1, y1+3))

    # Update the display
    pygame.display.flip()

    # Main loop
    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_ESCAPE: running = False

    pygame.quit()

# %%
# Function to draw a line using DDA
def draw_line_dda(x0, y0, x1, y1):
    # Calculate differences
    dx = x1 - x0
    dy = y1 - y0

    # Determine the number of steps
    steps = max(abs(dx), abs(dy))

    # Calculate increments
    x_inc = dx / steps if steps !=0 else 0
    y_inc = dy / steps if steps !=0 else 0

    # Initialize starting point
    x, y = x0, y0

    # Draw the line
    for s in range(steps+1):
        # screen.set_at((round(x),round(y)), Black)  # Plot the pixel
        # pygame.draw.line(screen, Blue, (round(x),round(y)),(round(x),round(y)), length)
        pygame.draw.rect(screen, Black, (round(x),round(y),length,length))
        # pygame.draw.circle(screen, Black, (round(x),round(y)), length, 0)
        x += x_inc
        y += y_inc

        # Remove the comment to step by step drawing
        # pygame.display.flip()



if __name__ == "__main__": 
    Black=(0,0,0)
    White=(255,255,255)

    # Set up display
    screen = pygame.display.set_mode((800, 600))
    pygame.display.set_caption("Digital Differential Analyzer (DDA) Algorithm")
    screen.fill(White)

    length=1
    x0, y0, x1, y1 = 50, 50, 700, 500  # Line endpoints
    draw_line_dda(x0, y0+i, x1, y1)
    pygame.display.flip()
    font = pygame.font.Font("freesansbold.ttf", 13)
    text_surface = font.render(f"({x0},{y0})", True, Black)
    screen.blit(text_surface, (x0, y0-17))
    text_surface = font.render(f"({x1},{y1})", True, Black)
    screen.blit(text_surface, (x1, y1+3))

    # Update the display
    pygame.display.flip()

    # Main loop
    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_ESCAPE: running = False

    pygame.quit()

# %%
# Draw a line using DDA
import pygame
pygame.init()

# Function to draw a line using DDA
def draw_line_dda(x0, y0, x1, y1):
    # Calculate differences
    dx = x1 - x0
    dy = y1 - y0

    # Determine the number of steps
    steps = max(abs(dx), abs(dy))

    # Calculate increments
    x_inc = dx / steps if steps !=0 else 0
    y_inc = dy / steps if steps !=0 else 0

    # Initialize starting point
    x, y =x0, y0

    # Draw the line
    for s in range(steps+1):
        px,py = round(x), round(y)
        screen.set_at((px,py), Black)  # Plot the pixel
        # pygame.draw.line(screen, Blue, (round(x),round(y)),(round(x),round(y)), length)
        pygame.draw.rect(screen, Black, (round(x),round(y),length,length))
        # pygame.draw.circle(screen, Black, (round(x),round(y)), length, 0)
        x += x_inc
        y += y_inc

        # Remove the comment to step by step drawing
        # pygame.display.flip()



if __name__ == "__main__": 
    Black=(0,0,0)
    White=(255,255,255)

    # Set up display
    screen = pygame.display.set_mode((800, 600))
    pygame.display.set_caption("Digital Differential Analyzer (DDA) Algorithm")
    screen.fill(White)

    length=1
    x0, y0, x1, y1 = 50, 50, 700, 500  # Line endpoints
    for i in range (0 , 5):
        draw_line_dda(x0, y0+i, x1, y1)
        pygame.display.flip()
    # font = pygame.font.Font("freesansbold.ttf", 13)
    # text_surface = font.render(f"({x0},{y0})", True, Black)
    # screen.blit(text_surface, (x0, y0-17))
    # text_surface = font.render(f"({x1},{y1})", True, Black)
    # screen.blit(text_surface, (x1, y1+3))

    # Update the display
    pygame.display.flip()

    # # Main loop
    # running = True
    # while running:
    #     for event in pygame.event.get():
    #         if event.type == pygame.KEYDOWN:
    #             if event.key == pygame.K_ESCAPE: running = False

    pygame.quit()

# %%
# Draw a line using DDA
import pygame
pygame.init()

# Function to draw a line using DDA
def draw_line_dda(x0, y0, x1, y1):
    # Calculate differences
    dx = x1 - x0
    dy = y1 - y0

    # Determine the number of steps
    steps = max(abs(dx), abs(dy))

    # Calculate increments
    x_inc = dx / steps if steps !=0 else 0
    y_inc = dy / steps if steps !=0 else 0

    # Initialize starting point
    x, y =x0, y0

    # Draw the line
    for _ in range(steps+1):
        px,py = round(x), round(y)
        # screen.set_at((px,py), Black)  # Plot the pixel
        # pygame.draw.line(screen, Blue, (round(x),round(y)),(round(x),round(y)), length)
        # pygame.draw.rect(screen, Black, (round(x),round(y),length,length))
        pygame.draw.rect(screen, Blue, (*scale_coords(x, y), length * PPI_SCALE, length * PPI_SCALE),1)
        # pygame.draw.circle(screen, Black, (round(x),round(y)), length, 0)
        x += x_inc
        y += y_inc

        # Remove the comment to step by step drawing
        pygame.display.flip()



if __name__ == "__main__":
    # Set logical resolution
    LOGICAL_WIDTH = 10
    LOGICAL_HEIGHT = 10
    PPI_SCALE = 10  # Increase to simulate higher PPI

    # Set actual window size
    WINDOW_WIDTH = LOGICAL_WIDTH * PPI_SCALE
    WINDOW_HEIGHT = LOGICAL_HEIGHT * PPI_SCALE

    pygame.init()
    screen = pygame.display.set_mode((WINDOW_WIDTH, WINDOW_HEIGHT))

    # Scale drawing
    def scale_coords(x, y):
        return int(x * PPI_SCALE), int(y * PPI_SCALE)


    # Define colors
    Black = (0, 0, 0)
    Red = (255, 0, 0)
    Blue = (0, 0, 255)
    White = (255, 255, 255)

    # Set up display
    screen = pygame.display.set_mode((800, 600))
    pygame.display.set_caption("Line Drawing Using Line Equation")
    screen.fill(White)

    length = 1 # Size of each "pixel"
    x0, y0, x1, y1 = 0, 0, 10, 40  # Line endpoints
    x0, y0, x1, y1 = 0, 0, 70, 30  # Line endpoints
    draw_line_dda(x0, y0, x1, y1)



    # Main loop
    running = True
    while running:
        for event in pygame.event.get():
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_ESCAPE:
                    running = False
        # Update the display
        pygame.display.flip()

    pygame.quit()
